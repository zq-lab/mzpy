# %%
import pandas as pd
from mzpy import peak

# %%
df = peak.read_msd_msp('d:/WorkBench/_code_/test_data/Msp_M1649.msp')
df.head(2)
# Out:
#   MSMS                               NAME  PRECURSORMZ PRECURSORTYPE  \
# 0   []  Unknown|ID=0|MZ=225.0292|RT=0.039    225.02924        [M+H]+
# 1   []  Unknown|ID=1|MZ=359.9465|RT=0.039    359.94650        [M+H]+
#
#     IONMODE  RETENTIONTIME                                            COMMENT  \
# 0  Positive       0.038797  |PEAKID=0|MS1SCAN=6|MS2SCAN=-1|PEAKHEIGHT=1341...
# 1  Positive       0.038797  |PEAKID=1|MS1SCAN=6|MS2SCAN=-1|PEAKHEIGHT=3328...
#
#    Num Peaks pkid  peak_height   peak_area
# 0          0    0    1341027.0  18176052.0
# 1          0    1      33282.0    114242.0

# %%
import mzpy

# %%
mzpy.__version__
# Out:
# '0.3.1'
