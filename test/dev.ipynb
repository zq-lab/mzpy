# %%
import pandas as pd

# %%
import numba

# %%
from mzpy import peak

# %%
df = peak.read_msd_msp_folder('')
# Out:
# reading:	\db_compound\测试集\msp_测试集\Msp_C00180.mspsp

# %%
df['file'].unique()
# Out:
# array(['\\db_compound\\测试集\\msp_测试集\\Msp_C00097_1.msp',
#        '\\db_compound\\测试集\\msp_测试集\\Msp_C00124.msp',
#        '\\db_compound\\测试集\\msp_测试集\\Msp_C00180.msp'], dtype=object)

# %%
df
# Out:
#                                                     MSMS  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 11435                                                 []
# 11436                                                 []
# 11437  [[57.07048, 2954.0], [70.06564, 5023.0], [88.0...
# 11438                                                 []
# 11439                                                 []
#
#                                        NAME  PRECURSORMZ PRECURSORTYPE  \
# 0         Unknown|ID=0|MZ=230.0187|RT=0.039    230.01868        [M+H]+
# 1         Unknown|ID=1|MZ=375.9042|RT=0.039    375.90424        [M+H]+
# ...
